# %%
import pandas as pd
import os
from src.extra_translate import extra
from src.variation_services_rest_db import VariationServicesRESTDataProxy
convert = extra()
converting_hgvs = VariationServicesRESTDataProxy()

# %%
current_dir = os.path.dirname(os.path.abspath('breakdown_complex_variation_definitions.ipynb'))
relative_path = os.path.join(current_dir, 'data', 'dbVar_structural_variants.csv')
data = pd.read_csv(relative_path)
data
# Out:
#    Variant Region ID                               Type  \
# 0         nsv3875336              copy number variation
# 1         nsv6312995              copy number variation
# 2         nsv5672872              copy number variation
# 3         nsv6137852              copy number variation
# 4         nsv7093597                          insertion
# 5         nsv6314514  complex chromosomal rearrangement
# 6         nsv3919275                          insertion
# 7         nsv4684390                             delins
# 8         nsv4578697                             delins
# 9         nsv4436066               complex substitution
# 10        nsv6638079                          inversion
# 11        nsv6314631  complex chromosomal rearrangement
# 12        nsv6314282  complex chromosomal rearrangement
# 13        nsv7093439                             delins
# 14        nsv7093572                          inversion
# 15        nsv4458037                 tandem duplication
# ...

# %%
def from_hgvs_to_spdi(expression):
    try: 
        # Converting a allele in SPDI syntax to the right-shifted HGVS notation
        return converting_hgvs.hgvs_to_spdi(expression)
    except Exception as e: 
        # returns error produce by NCBI API 
        return 'Error in expression {}'.format(e)

# %%
convert_to_spdi = []
correct_spdi_expression= []
spdi_expressions = []

index_of_incorrect_spdi_expr= []
index_of_correct_spdi_expr= []

for sample in df['description']:
    convert_to_spdi.append(from_hgvs_to_spdi(sample)) 

for idx,spdi in enumerate(convert_to_spdi):
    index_of_incorrect_spdi_expr.append(idx)
    if isinstance(spdi,list):
        index_of_correct_spdi_expr.append(idx)
        correct_spdi_expression.append(spdi)

for sublist in correct_spdi_expression:
    spdi_expressions.extend(sublist)

# %%
allForms = {
    'input_description' : df.iloc[index_of_correct_spdi_expr]['description'],
    'ga4gh_id' : [],
    'vrs_allele_object' : [],
    # 'spdi_expression' : correct_spdi_expression,
    # 'fullynorm_hgvs' : [],
    'rightshift_hgvs' : []
    }

vrs_object_list = []

for sample in spdi_expressions:
    allForms['rightshift_hgvs'].append(convert.to_rightshift_hgvs(sample))
    # allForms['fullynorm_hgvs'].append(convert.to_fullynorm_hgvs(sample))
    vrs_object_list.append(convert.to_vrs_allele(sample))  
    
for vrs_objects in vrs_object_list:
    for vrs_id in vrs_objects.keys():
        allForms['ga4gh_id'].append(vrs_objects.keys())
        allForms['vrs_allele_object'].append(vrs_objects[vrs_id])


allFormDF = pd.DataFrame.from_dict(allForms)

# %%
allFormDF
# Out:
#                                     input_description  \
# 7   NC_000009.11:g.108484281_108505262delinsAATTAA...
# 8                NC_000016.9:g.1569145_1571812delinsG
# 10           NC_000005.10:g.112818663_112819534inv872
# 13          NC_000010.11:g.101017287_101018201delinsT
# 14            NC_000020.11:g.50899224_50908772inv9549
# 19              NC_000023.11:g.13768220_13768286inv67
#
#                                        ga4gh_id  \
# 7   (ga4gh:VA.NEdt1t2Ak_hxAbdsgrrchZKbWFE05SkC)
# 8   (ga4gh:VA.61NVIrpqJfF0bd80g-3-3hWO10IGpOqb)
# 10  (ga4gh:VA.lRyFtt5JyBcrfTcQkvrch32ChQYdCF06)
# 13  (ga4gh:VA.KqqgYuCedDo9_DMeGsbm8AYBGyUdxs2u)
# 14  (ga4gh:VA.VaSFeT-EB60a3fqRqzeRWhOzZZmcETBe)
# 19  (ga4gh:VA.xeZrD37Ki00nCEcGA-mr7XHMMyuGmSiS)
#
#                                     vrs_allele_object  \
# 7   {'_id': 'ga4gh:VA.NEdt1t2Ak_hxAbdsgrrchZKbWFE0...
# 8   {'_id': 'ga4gh:VA.61NVIrpqJfF0bd80g-3-3hWO10IG...
# 10  {'_id': 'ga4gh:VA.lRyFtt5JyBcrfTcQkvrch32ChQYd...
# ...

# %%
allFormDF
# Out:
#                                       ga4gh_id  \
# 0  (ga4gh:VA.NEdt1t2Ak_hxAbdsgrrchZKbWFE05SkC)
# 1  (ga4gh:VA.61NVIrpqJfF0bd80g-3-3hWO10IGpOqb)
# 2  (ga4gh:VA.lRyFtt5JyBcrfTcQkvrch32ChQYdCF06)
# 3  (ga4gh:VA.KqqgYuCedDo9_DMeGsbm8AYBGyUdxs2u)
# 4  (ga4gh:VA.VaSFeT-EB60a3fqRqzeRWhOzZZmcETBe)
# 5  (ga4gh:VA.xeZrD37Ki00nCEcGA-mr7XHMMyuGmSiS)
#
#                                    vrs_allele_object  \
# 0  {'_id': 'ga4gh:VA.NEdt1t2Ak_hxAbdsgrrchZKbWFE0...
# 1  {'_id': 'ga4gh:VA.61NVIrpqJfF0bd80g-3-3hWO10IG...
# 2  {'_id': 'ga4gh:VA.lRyFtt5JyBcrfTcQkvrch32ChQYd...
# 3  {'_id': 'ga4gh:VA.KqqgYuCedDo9_DMeGsbm8AYBGyUd...
# 4  {'_id': 'ga4gh:VA.VaSFeT-EB60a3fqRqzeRWhOzZZmc...
# 5  {'_id': 'ga4gh:VA.xeZrD37Ki00nCEcGA-mr7XHMMyuG...
#
#                                      rightshift_hgvs
# 0  Error in expression Variation Services returne...
# 1               NC_000016.9:g.1569145_1571812delinsG
# 2              NC_000005.10:g.112818663_112819534inv
# ...

# %%
allFormDF
# Out:
#                                      rightshift_hgvs
# 0  Error in expression Variation Services returne...
# 1               NC_000016.9:g.1569145_1571812delinsG
# 2              NC_000005.10:g.112818663_112819534inv
# 3          NC_000010.11:g.101017287_101018201delinsT
# 4  Error in expression Variation Services returne...
# 5                NC_000023.11:g.13768220_13768286inv

# %%
import pandas as pd
from src.extra_translate import extra
convert = extra()

df = pd.read_csv('/Users/M278428/Documents/educational_notebooks/data/dbVar_structural_variants.csv')
df

# Creating a dictionary that contains all necessary formats. 
allForms = {
    'input_description' : df['description'],
    'ga4gh_id' : [],
    'vrs_allele_object' : [],
    'rightshift_hgvs' : [],
    'fullynorm_hgvs' : []
    }

vrs_object_list = []

# rightshift_hgvs is # out because the expressions are not in spdi expression, they are in hgvs expression. Not sure that you can make these expressions into spdi expressions.

for sample in df['description']:
    allForms['rightshift_hgvs' ].append(convert.to_rightshift_hgvs(sample))
    allForms['fullynorm_hgvs'].append(convert.to_fullynorm_hgvs(sample))
    vrs_object_list.append(convert.to_vrs_allele(sample))  
    
for vrs_objects in vrs_object_list:
    for vrs_id in vrs_objects.keys():
        allForms['ga4gh_id'].append(vrs_objects.keys())
        allForms['vrs_allele_object'].append(vrs_objects[vrs_id])


allFormDF = pd.DataFrame.from_dict(allForms)

index_of_correct_expr= []
index_of_incorrect_expr= []

for idx, expr in enumerate(allFormDF['vrs_allele_object']):
    if isinstance(expr,dict):
        index_of_correct_expr.append(idx)
    else:
        index_of_incorrect_expr.append(idx)

subset_df_correct_expr = allFormDF.iloc[index_of_correct_expr]
subset_df_error_expr = allFormDF.iloc[index_of_incorrect_expr]

subset_df_correct_expr
# Out:
#                                     input_description  \
# 7   NC_000009.11:g.108484281_108505262delinsAATTAA...
# 8                NC_000016.9:g.1569145_1571812delinsG
# 13          NC_000010.11:g.101017287_101018201delinsT
#
#                                        ga4gh_id  \
# 7   (ga4gh:VA.NEdt1t2Ak_hxAbdsgrrchZKbWFE05SkC)
# 8   (ga4gh:VA.61NVIrpqJfF0bd80g-3-3hWO10IGpOqb)
# 13  (ga4gh:VA.KqqgYuCedDo9_DMeGsbm8AYBGyUdxs2u)
#
#                                     vrs_allele_object  \
# 7   {'_id': 'ga4gh:VA.NEdt1t2Ak_hxAbdsgrrchZKbWFE0...
# 8   {'_id': 'ga4gh:VA.61NVIrpqJfF0bd80g-3-3hWO10IG...
# 13  {'_id': 'ga4gh:VA.KqqgYuCedDo9_DMeGsbm8AYBGyUd...
#
#                                       rightshift_hgvs  \
# 7   Error in expression Variation Services returne...
# 8   Error in expression Variation Services returne...
# 13  Error in expression Variation Services returne...
#
#                                        fullynorm_hgvs
# ...

# %%
variations = {}

for types in df['Type'].unique():
    variations[types] = df[df['Type'] == types ].description.values

# %% [markdown]
# #### Copy Number Variation

# %%
variations['copy number variation']

# %% [markdown]
# Breakdown
#
# 1) ? is used to indicate unknown positions
# 2) x means the number of duplication

# %% [markdown]
# #### Insertion

# %%
variations['insertion']

# %% [markdown]
# Breakdown
#
# 1) N means the sequencer was not able to make a basecall for this base
# 2) .. indicates that the variation occurs somewhere between the genomic positions 12243 and 12314, but the exact location of the variation is not specified
#
# Links
#
# * https://www.ncbi.nlm.nih.gov/clinvar/variation/13823/

# %% [markdown]
# #### Complex Chromosomal Rearrangement

# %%
variations['complex chromosomal rearrangement']

# %% [markdown]
# Breakdown
#
# 1) t means translocations
# 2) inv means inversion
# 3) dn means de novo
# 4) ; (semi colon) is used to separate variants and alleles

# %% [markdown]
# #### Delins

# %%
variations['delins']

# %% [markdown]
# Breakdown
#
# 1) “fs” indicates a frame shift

# %% [markdown]
# #### Complex Substitution????????????????????

# %%
variations['complex substitution']

# %% [markdown]
# #### Inversion

# %%
variations['inversion']

# %% [markdown]
# #### Tandem Duplication

# %%
variations['tandem duplication']

# %%
subset_df_correct_expr
# subset_df_error_expr

# %% [markdown]
# This HGVS genomic descriptor provides information about a genetic variation in the GLI3 gene. Let's break it down:
#
# NM_000168.5: This is the RefSeq accession number for the mRNA sequence of the GLI3 gene.
#
# (GLI3): This indicates the gene symbol, which in this case is GLI3.
#
# :c.2770_2771ins: This part of the descriptor describes the genomic change that occurred. "c." stands for coding sequence, and "2770_2771" indicates that the variation occurred at nucleotide positions 2770 and 2771. "ins" indicates that there was an insertion of additional nucleotides at this location.
#
# NC_012920.1: This is the RefSeq accession number for the genomic sequence that the variation is being described relative to.
#
# :g.12243..12314: This part of the descriptor describes the genomic location of the variation. "g." stands for genomic coordinate, and "12243..12314" indicates the range of positions on the genomic sequence where the variation occurs.
#
# Putting it all together, we can interpret this HGVS genomic descriptor as follows:
#
# In the GLI3 gene, there was an insertion of nucleotides at positions 2770 and 2771 in the coding sequence, relative to the RefSeq mRNA sequence with accession number NM_000168.5. This variation occurs on the genomic sequence with accession number NC_012920.1 between positions 12243 and 12314.
#
# It's worth noting that interpreting genomic descriptors like this one can be complex and requires knowledge of genetics and genomics. It's important to consult with a genetic counselor or other qualified healthcare provider for accurate interpretation and guidance on any genetic testing or treatment decisions.

# %% [markdown]
# This genomic descriptor is describing a chromosomal abnormality in a female with a karyotype of 46,XX, meaning she has 46 total chromosomes and two X chromosomes. The descriptor is using the International System for Human Cytogenomic Nomenclature (ISCN) to describe the chromosomal changes.
#
# The abnormality involves a derivative chromosome 9, which is formed by the fusion of two regions from the long arm (q) of chromosome 9, specifically from bands q21.2 to q21.2. The "der(9)(q21.2,q21.2)" part of the descriptor specifies this.
#
# The sequence coordinate system used in this descriptor is GRCh37/hg19, which is a reference genome assembly used in genetic research.
#
# The next part of the descriptor describes the specific breakpoints and rearrangements on the derivative chromosome 9. The "seq" keyword indicates that the description is now in genomic coordinates. The descriptor describes several changes, separated by double colons "::", on the derivative chromosome 9:
#
# "9pter->9q21.2(+)(8084369{7-8})" indicates that the short arm of chromosome 9, also known as "9p", is translocated to the q21.2 region on the derivative chromosome 9, resulting in a gain of genetic material. The "(+)" indicates that the translocation is in the forward direction, and the "8084369{7-8}" indicates the exact position on the reference genome where the breakpoint occurred.
#
# "q21.2(-)(808497{60-59})" indicates that the q21.2 region on the original chromosome 9, which is now on the derivative chromosome 9, is deleted. The "(-)" indicates that the deletion is in the reverse direction, and the "808497{60-59}" indicates the exact position on the reference genome where the deletion occurred.
#
# "q21.2(-)(8084946{5-3})" indicates that another part of the q21.2 region on the derivative chromosome 9 is deleted. The "8084946{5-3}" indicates the exact position on the reference genome where the deletion occurred.
#
# "q21.2(+)(808596{79-81}->9qter)" indicates that another part of the q21.2 region on the derivative chromosome 9 is duplicated and translocated to the qter (end) of chromosome 9. The "(+)" indicates that the translocation is in the forward direction, and the "808596{79-81}" indicates the exact position on the reference genome where the duplication occurred.
#
# Overall, this genomic descriptor describes a complex rearrangement involving the q21.2 region of chromosome 9, resulting in a derivative chromosome 9 with multiple changes in genetic material.
